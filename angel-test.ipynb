# %%
import os
from music21 import converter, instrument, note, chord
import pandas as pd

# Define the dataset path
dataset_path = r"C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI"

# Function to parse MIDI files and extract notes
def parse_midi(file):
    try:
        notes = []
        midi = converter.parse(file)
        parts = instrument.partitionByInstrument(midi)
        if parts:  # File has instrument parts
            notes_to_parse = parts.parts[0].recurse()
        else:  # File has notes in flat structure
            notes_to_parse = midi.flat.notes

        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

        return notes
    except Exception as e:
        print(f"Error parsing {file}: {e}")
        return []

# Initialize lists for data and labels
data = []
labels = []

# Define the composers
composers = ['Bach', 'Beethoven', 'Chopin', 'Mozart']

# Recursively search for MIDI files in subdirectories
midi_files = []
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.lower().endswith('.mid'):
            midi_files.append(os.path.join(root, file))

print(f"Found {len(midi_files)} MIDI files.")

for file in midi_files:
    # Extract the composer name from the directory name
    directory_name = os.path.basename(os.path.dirname(file))
    composer = None
    if directory_name in composers:
        composer = directory_name
    else:
        print(f"Skipping {file}, directory name {directory_name} does not match any composer.")
        continue

    print(f"Parsing {file} as {composer}")
    notes = parse_midi(file)
    if notes:  # Only add if parsing was successful
        data.append(notes)
        labels.append(composer)
    else:
        print(f"Failed to parse {file}")

# Check if data is collected
if not data:
    print("No data collected. Please check the MIDI files and parsing logic.")
else:
    # Convert lists to DataFrame
    df = pd.DataFrame({'notes': data, 'label': labels})
    df.to_csv('labeled_midi.csv', index=False)

    # Print the first few rows of the DataFrame to inspect
    print(df.head())

    # Display sample notes and their corresponding labels
    for i in range(min(5, len(data))):  # Adjust range based on available samples
        print(f"Sample {i+1}:")
        print(f"Label: {labels[i]}")
        print(f"Notes: {data[i][:20]}")  # Print the first 20 notes for brevity
        print()

    # Check the distribution of labels
    label_counts = df['label'].value_counts()
    print("Label distribution:")
    print(label_counts)
# Out:
# Found 1633 MIDI files.
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\AveMaria.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0525 Sonate en trio n1.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0526 Sonate en trio n2.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0527 Sonate en trio n3.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0528 Sonate en trio n4.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0529 Sonate en trio n5.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0530 Sonate en trio n6.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0531 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0532 Toccata and Fugue.mid as Bach
# Failed to parse C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0532 Toccata and Fugue.mid
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0533 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0535 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0536 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0537 Fantasia and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0538 Toccata and Fugue ''Dorian''.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0539 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0540 Toccata and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0541 Prelude and Fugue.mid as Bach
# Failed to parse C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0541 Prelude and Fugue.mid
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0542 Fantasia and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0543 Prelude and Fugue.mid as Bach
# Failed to parse C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0543 Prelude and Fugue.mid
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0544 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0546 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0547 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0549 Prelude and Fugue.mid as Bach
# Failed to parse C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0549 Prelude and Fugue.mid
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0550 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0551 Prelude and Fugue.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0552 Prelude and Fugue ''St. Anne''.mid as Bach
# Failed to parse C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0552 Prelude and Fugue ''St. Anne''.mid
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0554 Short Prelude and Fugue n2 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0555 Short Prelude and Fugue n3 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0556 Short Prelude and Fugue n4 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0557 Short Prelude and Fugue n5 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0558 Short Prelude and Fugue n6 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0559 Short Prelude and Fugue n7 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0560 Short Prelude and Fugue n8 (Spurious).mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv0561 Fantasie and Fuga.mid as Bach
# Parsing C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Bach\Bwv
.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n36 K425 2mov ''Linz''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n36 K425 3mov ''Linz''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n36 K425 4mov ''Linz''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n37 K444 1mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n38 K504 1mov ''Prague''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n38 K504 2mov ''Prague''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n38 K504 3mov ''Prague''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n39 K543 1mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n39 K543 2mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n39 K543 3mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n39 K543 4mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n4 K019 1mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n4 K19 3mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n40 K550 1mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n40 K550 2mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n40 K550 3mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n40 K550 4mov.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n41 K551 1mov ''Jupiter''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n41 K551 2mov ''Jupiter''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n41 K551 3mov ''Jupiter''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n41 K551 4mov ''Jupiter''.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\Symphonies\Symphony n5 K022.mid, directory name Symphonies does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n1 Andante.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n10 Air.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n11 Country dance.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n12 Rondino.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n13 Prelude.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n14 Rondo.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n15 Andantino.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n16 Minuet.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n17 Siciliano.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n18 Little Song.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n19 Giga.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n2 Minuet.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n20 Presto.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n3 Little march.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n4 Minuet.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n5 Country Dance.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n6 Llittle minuet.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n7 Country dance.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n8 Minuet.mid, directory name The Chelsea Notebook does not match any composer.
# Skipping C:\Users\eterp\OneDrive\Documents\USD\Neural Networks and Deep Learning (AAI-511-04)\MIDI\Mozart\The Chelsea Notebook\Early Pieces n9 Allegretto.mid, directory name The Chelsea Notebook does not match any composer.
#                                                notes label
# 0  [F3, A3, C4, F4, A4, C4, F4, A4, F3, A3, C4, F...  Bach
# 1  [E-3, G3, F3, G3, C3, E-3, D3, E-3, G#2, B-2, ...  Bach
# 2  [G5, E-4, D4, E-4, F4, G4, G5, 5.7, F5, E-5, F...  Bach
# 3  [F5, E5, D5, 1.2, C#5, D5, D5, E5, D5, C#5, D5...  Bach
# 4  [E4, G4, B4, C4, C4, 2.4, 0.2, C4, B3, B3, B4,...  Bach
# Sample 1:
# Label: Bach
# Notes: ['F3', 'A3', 'C4', 'F4', 'A4', 'C4', 'F4', 'A4', 'F3', 'A3', 'C4', 'F4', 'A4', 'C4', 'F4', 'A4', 'F3', 'G3', 'D4', 'G4']
#
# Sample 2:
# Label: Bach
# Notes: ['E-3', 'G3', 'F3', 'G3', 'C3', 'E-3', 'D3', 'E-3', 'G#2', 'B-2', 'E-2', 'E-3', 'D3', 'C3', 'B-4', 'D3', 'D5', 'F3', 'F5', 'D3']
#
# Sample 3:
# Label: Bach
# Notes: ['G5', 'E-4', 'D4', 'E-4', 'F4', 'G4', 'G5', '5.7', 'F5', 'E-5', 'F5', 'D4', 'C4', 'D4', 'E-4', 'F4', 'F5', '3.5', 'E-5', 'D5']
#
# Sample 4:
# Label: Bach
# Notes: ['F5', 'E5', 'D5', '1.2', 'C#5', 'D5', 'D5', 'E5', 'D5', 'C#5', 'D5', 'E5', 'F5', 'G5', 'A5', 'B-5', 'A5', 'G5', 'F5', 'E5']
#
# Sample 5:
# Label: Bach
# Notes: ['E4', 'G4', 'B4', 'C4', 'C4', '2.4', '0.2', 'C4', 'B3', 'B3', 'B4', 'A4', 'G4', 'F#4', 'E4', 'C5', 'B4', 'C5', 'A4', 'E-4']
#
# Label distribution:
# label
# Bach         93
# Beethoven    79
# Chopin       75
# Mozart       54
# Name: count, dtype: int64
